# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
X = np.array([[1, 2, 1, 1],
 [2, 2, 1, 2],
 [3, 2, 1, 2],
 [4, 2, 1, 2],
 [5, 2, 1, 2]])


y = np.array([1, 1, 0, 1, 0])  # Now has both class 0 and class 1

model = LogisticRegression()

model.fit(X, y)
# Out:
# LogisticRegression()

# %%
import psutil
cpu_usage = psutil.cpu_percent(interval=1)
per_core_usage = psutil.cpu_percent(interval=1, percpu=True)
physical_cores = psutil.cpu_count(logical=False)
logical_cpus = psutil.cpu_count(logical=True)
cpu_freq = psutil.cpu_freq()
load_avg = psutil.getloadavg()

# %%
s = set()
s.add(1)
s.add(2)
list(s).index(1)
# Out:
# 0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# Generate a synthetic dataset
X, y = make_classification(n_samples=100, n_features=10, random_state=42)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Get the probabilities for the test set
probabilities = model.predict_proba(X_test)

# The output probabilities are for each class
# probabilities[:, 1] gives the probability of the positive class
print("Probabilities:\n", probabilities)
# Out:
# Probabilities:
#  [[7.49632742e-01 2.50367258e-01]
#  [5.71492961e-02 9.42850704e-01]
#  [8.47383467e-03 9.91526165e-01]
#  [3.84386602e-02 9.61561340e-01]
#  [2.79853023e-02 9.72014698e-01]
#  [9.64640318e-01 3.53596817e-02]
#  [9.65369374e-01 3.46306260e-02]
#  [2.13024820e-01 7.86975180e-01]
#  [2.27546362e-01 7.72453638e-01]
#  [1.81401566e-01 8.18598434e-01]
#  [9.87298049e-01 1.27019510e-02]
#  [1.84390109e-03 9.98156099e-01]
#  [1.11638160e-03 9.98883618e-01]
#  [9.98846835e-01 1.15316489e-03]
#  [3.19528899e-03 9.96804711e-01]
#  [9.75335190e-01 2.46648100e-02]
#  [2.79003416e-02 9.72099658e-01]
#  [9.72840626e-01 2.71593739e-02]
#  [9.57717728e-01 4.22822718e-02]
#  [9.96764165e-01 3.23583540e-03]
#  [3.26255970e-02 9.67374403e-01]
#  [9.91543744e-01 8.45625612e-03]
#  [6.48321099e-01 3.51678901e-01]
#  [9.99581102e-01 4.18898067e-04]
#  [4.12860534e-01 5.87139466e-01]
#  [2.88332431e-02 9.71166757e-01]
#  [2.12154089e-03 9.97878459e-01]
#  [6.02847763e-02 9.39715224e-01]
#  [3.75991026e-01 6.24008974e-01]
#  [9.83390544e-04 9.99016609e-01]]

# %%
s = set()
s.add((1, 2))
s.add((0,3))
s
# Out:
# {(0, 3), (1, 2)}

# %%
import psutil

# Get the percentage of CPU usage
cpu_usage = psutil.cpu_percent()  # interval in seconds
print(f"CPU Usage: {cpu_usage}%")

# Get the per-core CPU usage
per_core_usage = sum(psutil.cpu_percent(percpu=True))/psutil.cpu_count()
print(f"Per-Core CPU Usage: {per_core_usage}")

# Get the number of physical cores and logical CPUs
physical_cores = psutil.cpu_count(logical=False)
logical_cpus = psutil.cpu_count(logical=True)
print(f"Physical Cores: {physical_cores}, Logical CPUs: {logical_cpus}")

# Get the current CPU frequency
cpu_freq = psutil.cpu_freq()
print(f"Current CPU Frequency: {cpu_freq.current} MHz")

# Get CPU load averages (1, 5, 15 minutes)
load_avg = psutil.getloadavg()
print(f"CPU Load Average (1, 5, 15 min): {load_avg}")
# Out:
# CPU Usage: 30.2%
# Per-Core CPU Usage: 49.275
# Physical Cores: 8, Logical CPUs: 16
# Current CPU Frequency: 3201.0 MHz
# CPU Load Average (1, 5, 15 min): (0.02, 0.01, 0.0)

# %%
# x = [[0.     0.     4.     8.    ]
#  [0.     0.     4.     8.    ]
#  [4.     3.9875 4.     8.    ]
#  [2.7    2.7    4.     8.    ]
#  [5.1    5.0125 4.     8.    ]
#  [6.1    6.0125 4.     8.    ]
#  [3.6    3.625  4.     8.    ]
#  [4.5    4.5125 4.     8.    ]
#  [3.8    3.7375 4.     8.    ]
#  [2.6    2.525  4.     8.    ]]

x = np.array([[0., 0., 4., 8.],
    [0., 0., 4., 8.],
    [4., 3.9875, 4., 8.],
    [2.7, 2.7, 4., 8.],
    [5.1, 5.0125, 4., 8.],
    [6.1, 6.0125, 4., 8.],
    [3.6, 3.625, 4., 8.],
    [4.5, 4.5125, 4., 8.],
    [3.8, 3.7375, 4., 8.],
    [2.6, 2.525, 4., 8.]])
y = np.array([0, 0, 1, 1, 0, 1, 1, 0, 0, 0])

# %%
model = LogisticRegression()
model.fit(x, y)
# Out:
# LogisticRegression()

# %%
import psutil
cpu_usage = psutil.cpu_percent()
per_core_usage = sum(psutil.cpu_percent(percpu=True))/psutil.cpu_count()
physical_cores = psutil.cpu_count(logical=False)
logical_cpus = psutil.cpu_count(logical=True)
print(f"CPU Usage: {cpu_usage}, Per Core Usage: {per_core_usage}, Physical Cores: {physical_cores}, Logical CPUs: {logical_cpus}")
try:
    proba = model.predict([[cpu_usage, per_core_usage, physical_cores, logical_cpus]])
    print(proba)
except Exception as e:
    print(f"Error predicting probabilities: {e}")
    proba = 0
# Out:
# CPU Usage: 32.8, Per Core Usage: 32.8125, Physical Cores: 8, Logical CPUs: 16
# [1]

# %%
v = str(set([(12, 'a')]))

# %%
eval(v)
# Out:
# {(12, 'a')}

# %%
temp = eval(v)

# %%
temp
# Out:
# {(12, 'a')}

# %%
temp.add((12, 'a'))

# %%
temp
# Out:
# {(12, 'a')}

# %%
s = set()
s.add(3)
s.add(1)
s.add(2)

# %%
s
# Out:
# {1, 2, 3}

# %%
list(s)
# Out:
# [1, 2, 3]

# %%
parameters = {5001: {'ss': 0, 'lit': 0, 'aist': 0, 'cst': 0, 'tst': 2, 'cbm': 0}, 5002: {'ss': 0, 'lit': 2, 'aist': 2.0, 'cst': 1, 'tst': 2, 'cbm': 1}}

# %%
validators = [5001, 5002]
def score(params):
        """
        Consensus Score (CS) = [α * AIST * (1 - CST/TST) * log(1 + 1/LIT)] / [β * (CBM + 1)]
        """
        alpha = 3
        beta = 1
        aist = params['aist']
        cst = params['cst']
        tst = params['tst']
        lit = params['lit']
        cbm = params['cbm']
        
        if cst == 0:
            aist = len(validators) * 2
        if cst == 1:
            aist = len(validators)

        CS = (alpha * aist * (1 - cst/tst) * np.log(1 + 1/(lit + 0.00001))) / (beta * (cbm + 1))
        # CS = (alpha * params['aist'] * (1 - params['cst']/params['tst']) * np.log(1 + 1/params['lit'])) / (beta * (params['cbm'] + 1))
        return CS

# %%
CS = [score(parameters[val]) for val in validators]

# %%
import threading
import time
import random
import poem_global as poem
import aasc as aasc
from tabulate import tabulate

class Test:
    def __init__(self, test_type = 'throughput'):
        self.test_type = test_type

    def create_network(self, num_nodes, num_miners):
        assert num_nodes >= num_miners
        nodes = [5000 + i for i in range(num_nodes)]
        validators = random.sample(nodes, num_miners)

        edges = []
        shuffled_nodes = nodes[:]
        random.shuffle(shuffled_nodes)
        
        for i in range(1, num_nodes):
            u = shuffled_nodes[i]
            v = shuffled_nodes[random.randint(0, i - 1)]
            edges.append((u, v))
        
        possible_edges = [
            (u, v) for i, u in enumerate(nodes) for v in nodes[i + 1:]
            if (u, v) not in edges and (v, u) not in edges
        ]
        
        random.shuffle(possible_edges)
        extra_edges = random.randint(0, len(possible_edges))
        
        for _ in range(extra_edges):
            edges.append(possible_edges.pop())   

        return nodes, validators, edges
    
    def run_node(port, is_validator, address = '127.0.0.1', algo = aasc):
        node = algo.Node(address, port, is_validator)
        cli = algo.NodeCLI(node)
        
        node_thread = threading.Thread(target=node.start)
        node_thread.start()
        
        return node, cli
    
    def run_test(self, num_nodes, num_miners):
        nodes, validators, edges = self.create_network(num_nodes, num_miners)
        
        print(f"Running test for {num_nodes} nodes and {num_miners} miners")
        aasc_result = self.AASC_test(nodes, validators, edges)
        print("AASC Test Completed")
        poem_result = self.PoEM_test(nodes, validators, edges)
        print("PoEM Test Completed")

        result = {
            'AASC' : aasc_result,
            'PoEM' : poem_result
        }

        table = []
        for algo, result in result.items():
            table.append([algo, result['throughput'], result['latency']])
        
        print(f"Test Results for {num_nodes} nodes and {num_miners} miners")
        print("-" * 50)
        print(tabulate(table, headers = ['Algorithm', 'Throughput', 'Latency']))
        print("-" * 50)

        

    def AASC_test(self, nodes, validators, edges):
        active_nodes = {node : self.run_node(node, node in validators, algo = aasc) for node in nodes}
        for u, v in edges:
            active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
        
        active_nodes[nodes[0]][1].do_sval("")

        transaction_nodes = random.sample(nodes, len(nodes) // 2)
        transaction_per_nodes = 1000//len(transaction_nodes)
        total_transactions = 0
        start_time = time.time()
        for node in transaction_nodes:
            for _ in range(transaction_per_nodes):
                recipient = f"user{random.randint(1, 100)}"
                amount = random.randint(1, 10)
                active_nodes[node][1].do_addtx(f"{recipient} {amount}")
                total_transactions += 1
        end_time = time.time()
        total_time = end_time - start_time
        throughput = total_transactions / total_time
        latency = total_time / total_transactions

        result = {
            'throughput' : throughput,
            'latency' : latency
        }
        return result


    def PoEM_test(self, nodes, validators, edges):
        active_nodes = {node : self.run_node(node, node in validators, algo = poem) for node in nodes}
        for u, v in edges:
            active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
        
        active_nodes[nodes[0]][1].do_sval("")

        transaction_nodes = random.sample(nodes, len(nodes) // 2)
        transaction_per_nodes = 1000//len(transaction_nodes)
        total_transactions = 0
        start_time = time.time()
        for node in transaction_nodes:
            for _ in range(transaction_per_nodes):
                recipient = f"user{random.randint(1, 100)}"
                amount = random.randint(1, 10)
                active_nodes[node][1].do_addtx(f"{recipient} {amount}")
                total_transactions += 1
        end_time = time.time()
        total_time = end_time - start_time
        throughput = total_transactions / total_time
        latency = total_time / total_transactions

        result = {
            'throughput' : throughput,
            'latency' : latency
        }
        return result

# %%
test = Test()
test.run_test(3, 2)
# Out:
# Exception in thread Thread-4 (start):
# Traceback (most recent call last):
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-5 (start):
# Traceback (most recent call last):
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-6 (start):
# Traceback (most recent call last):
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\mohit\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.run()
#   File "C:\Users\mohit\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.run()
#   File "C:\Users\mohit\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 982, in run
#     _threading_Thread_run(self)
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 982, in run
#     _threading_Thread_run(self)
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\mohit\Desktop\blockchain-python\aasc.py", line 111, in start
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\mohit\Desktop\blockchain-python\aasc.py", line 111, in start
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\mohit\Desktop\blockchain-python\aasc.py", line 111, in start
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
# Running test for 3 nodes and 2 miners
# Exception in thread Thread-7 (start):
# Traceback (most recent call last):
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-8 (start):
# Traceback (most recent call last):
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-9 (start):
# Traceback (most recent call last):
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\mohit\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.run()
#   File "C:\Users\mohit\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     self.run()
#   File "C:\Users\mohit\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 982, in run
#     _threading_Thread_run(self)
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 982, in run
#     _threading_Thread_run(self)
#   File "c:\Users\mohit\miniconda3\envs\nlp\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\mohit\Desktop\blockchain-python\poem_global.py", line 260, in start
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\mohit\Desktop\blockchain-python\poem_global.py", line 260, in start
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\mohit\Desktop\blockchain-python\poem_global.py", line 260, in start
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
#     s.bind((self.address, self.port))
# TypeError: str, bytes or bytearray expected, not bool
# AASC Test Completed
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# ...
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# Invalid input. Use format: addtx <recipient> <amount>
# Total of weights must be greater than zero
# PoEM Test Completed
# Test Results for 3 nodes and 2 miners
# --------------------------------------------------
# Algorithm      Throughput      Latency
# -----------  ------------  -----------
# AASC              11171.2  8.95157e-05
# PoEM              10738.9  9.31191e-05
# --------------------------------------------------

# %%
import threading
import time
import random
import poem_global as poem
import aasc as aasc
from tabulate import tabulate

class Test:
    def __init__(self, test_type = 'throughput', number_of_transactions = 200):
        self.test_type = test_type
        self.number_of_transactions = number_of_transactions

    def create_network(self, num_nodes, num_miners):
        assert num_nodes >= num_miners
        nodes = [6000 + i for i in range(num_nodes)]
        validators = random.sample(nodes, num_miners)

        edges = []
        shuffled_nodes = nodes[:]
        random.shuffle(shuffled_nodes)
        
        for i in range(1, num_nodes):
            u = shuffled_nodes[i]
            v = shuffled_nodes[random.randint(0, i - 1)]
            edges.append((u, v))
        
        possible_edges = [
            (u, v) for i, u in enumerate(nodes) for v in nodes[i + 1:]
            if (u, v) not in edges and (v, u) not in edges
        ]
        
        random.shuffle(possible_edges)
        extra_edges = random.randint(0, len(possible_edges))
        
        for _ in range(extra_edges):
            edges.append(possible_edges.pop())   

        print("Nodes: ", nodes)
        print("Validators: ", validators)
        print("Edges: ", edges)
        return nodes, validators, edges
    
    def run_node(self, port, is_validator, address = '127.0.0.1', algo = aasc):
        print(f"Running node on port {port}, is_validator: {is_validator}, address: {address}")
        node = algo.Node(address, port, is_validator)
        cli = algo.NodeCLI(node)
        
        node_thread = threading.Thread(target=node.start)
        node_thread.start()
        
        return node, cli
    
    def run_test(self, num_nodes, num_miners):
        nodes, validators, edges = self.create_network(num_nodes, num_miners)
        
        print(f"Running test for {num_nodes} nodes and {num_miners} miners")
        aasc_result = self.AASC_test(nodes, validators, edges)
        print("AASC Test Completed")
        # poem_result = self.PoEM_test(nodes, validators, edges)
        # print("PoEM Test Completed")
    
        # result = {
        #     'AASC' : aasc_result,
        #     'PoEM' : poem_result
        # }

        # table = []
        # for algo, result in result.items():
        #     table.append([algo, result['throughput'], result['latency']])
        
        # print(f"Test Results for {num_nodes} nodes and {num_miners} miners")
        # print("-" * 50)
        # print(tabulate(table, headers = ['Algorithm', 'Throughput', 'Latency']))
        # print("-" * 50)

        

    def AASC_test(self, nodes, validators, edges):
        print(f"AASC Nodes {nodes}")
        for node in nodes:
            print(node)
        active_nodes = {node : self.run_node(node, node in validators, algo = aasc) for node in nodes}
        print("Attempting to connect nodes")
        for u, v in edges:
            active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
            time.sleep(1)
        
        time.sleep(2)
        print("Collecting validators")
        active_nodes[nodes[0]][1].do_sval("")
        time.sleep(2)
        transaction_nodes = random.sample(nodes, len(nodes) // 2)
        transaction_per_nodes = self.number_of_transactions//len(transaction_nodes)
        total_transactions = 0
        print("Starting transactions")
        start_time = time.time()
        for node in transaction_nodes:
            for _ in range(transaction_per_nodes):
                recipient = f"user{random.randint(1, 100)}"
                amount = random.randint(1, 10)
                active_nodes[node][1].do_addtx(f"{recipient} {amount}")
                total_transactions += 1
                print(f"Transaction {total_transactions} completed", end = '\r')
        end_time = time.time()
        for node in nodes:
            active_nodes[node][1].do_viewchain("")

        total_time = end_time - start_time
        throughput = total_transactions / total_time
        latency = total_time / total_transactions

        result = {
            'throughput' : throughput,
            'latency' : latency
        }

        time.sleep(2)
        for node in nodes:
            active_nodes[node][1].do_exit("")

        return result


    def PoEM_test(self, nodes, validators, edges):
        active_nodes = {node : self.run_node(node, node in validators, algo = poem) for node in nodes}
        print("Attempting to connect nodes")
        for u, v in edges:
            active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")

        time.sleep(2)
        print("Collecting validators")
        active_nodes[nodes[0]][1].do_sval("")
        time.sleep(2)

        transaction_nodes = random.sample(nodes, len(nodes) // 2)
        transaction_per_nodes = self.number_of_transactions//len(transaction_nodes)
        total_transactions = 0
        print("Starting transactions")
        start_time = time.time()
        for node in transaction_nodes:
            for _ in range(transaction_per_nodes):
                recipient = f"user{random.randint(1, 100)}"
                amount = random.randint(1, 10)
                active_nodes[node][1].do_addtx(f"{recipient} {amount}")
                total_transactions += 1
                print(f"Transaction {total_transactions} completed", end = '\r')
        end_time = time.time()
        for node in nodes:
            print(f"Viewing chain for node {node}")
            print(active_nodes[node][1].do_count(""))
        total_time = end_time - start_time
        throughput = total_transactions / total_time
        latency = total_time / total_transactions

        result = {
            'throughput' : throughput,
            'latency' : latency
        }

        time.sleep(2)
        for node in nodes:
            active_nodes[node][1].do_exit("")

        return result

# %%
test = Test(number_of_transactions=10)
nodes, validators, edges = test.create_network(6, 4)
# Out:
# Nodes:  [6000, 6001, 6002, 6003, 6004, 6005]
# Validators:  [6001, 6002, 6005, 6003]
# Edges:  [(6005, 6003), (6000, 6005), (6001, 6000), (6002, 6000), (6004, 6005), (6002, 6004), (6001, 6005), (6000, 6003), (6001, 6004), (6001, 6002), (6002, 6005)]

# %%
active_nodes = {node : test.run_node(node, node in validators, algo = aasc) for node in nodes}
# Out:
# Running node on port 6000, is_validator: False, address: 127.0.0.1
# Running node on port 6001, is_validator: True, address: 127.0.0.1
# Running node on port 6002, is_validator: True, address: 127.0.0.1
# Running node on port 6003, is_validator: True, address: 127.0.0.1
# Running node on port 6004, is_validator: False, address: 127.0.0.1
# Running node on port 6005, is_validator: True, address: 127.0.0.1

# %%
for u, v in edges:
    active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
    time.sleep(1)

# %%
active_nodes[u][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None

# %%
active_nodes[nodes[0]][1].do_sval("")

# %%
active_nodes[nodes[0]][1].do_val("")
# Out:
# Validators: {6001, 6002, 6003, 6005}

# %%
active_nodes[nodes[0]][1].do_addtx("user1 10")

# %%
active_nodes[nodes[1]][1].do_addtx("user15 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003

# %%
active_nodes[nodes[1]][1].do_addtx("user1 10")

# %%
for node in nodes:
    active_nodes[node][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 9a0af26e080766f7e75855500d32d74abd385e4e86acebc54a0cf2f81d381644
#   Previous Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 9a0af26e080766f7e75855500d32d74abd385e4e86acebc54a0cf2f81d381644
#   Previous Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 9a0af26e080766f7e75855500d32d74abd385e4e86acebc54a0cf2f81d381644
#   Previous Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 9a0af26e080766f7e75855500d32d74abd385e4e86acebc54a0cf2f81d381644
#   Previous Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 9a0af26e080766f7e75855500d32d74abd385e4e86acebc54a0cf2f81d381644
#   Previous Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Mined by: 6003
#
# Block 0:
#   Timestamp: 1768915451
#   Data: Genesis Block
#   Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Previous Hash: 4c653491e83403c026d9021ff7fddab12a7af022e15ada441bf54cae2aaf79db
#   Mined by: 6002
#
# Block 2:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user15']
#   Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Previous Hash: 168caf09ddfac1b65f52ff70785ccfd90c1159adcf35b20b07f5cb89f9b0ae39
#   Mined by: 6002
#
# Block 3:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Previous Hash: 30933c1546535f474f9f950a56ed004d5e5551c7a5fff3c7e4713f56a50d8c42
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Previous Hash: 0ed4df36625b07bb1bb011f7dce9ec0ccfe1d33ff9a4c030964444b2ec9600a5
#   Mined by: 6001
#
# Block 5:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Previous Hash: fd8fa975c35fe2824f02d3ad3a774cba7aede97fa9b431c87504aba321c85d17
#   Mined by: 6001
#
# Block 6:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Previous Hash: 6c7ab3c91e4566f494bb8fb236f2ed15eaec132b31997e76dc0e1bec918dbe75
#   Mined by: 6001
#
# Block 7:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Previous Hash: 255401f8da84d86add4efacc99f8b4dcf93317ca28dbb63444c033aa9fc28104
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1768915463
#   Data: ['127.0.0.16001 sends 10 coins to user1']
#   Hash: 9a0af26e080766f7e75855500d32d74abd385e4e86acebc54a0cf2f81d381644
#   Previous Hash: cdb608ffa56e47c40ed2e29f65ba0f005c95a985ee9c7231a3e418d1bb705f5a
#   Mined by: 6003

# %%
a = {1: 2, 3: 4}
b = {3: 6, 7: 8}
a.update(b)
a
# Out:
# {1: 2, 3: 6, 7: 8}

# %%
import pos as pos
import threading
import time
def run_node(port, is_validator, address = '127.0.0.1', algo = pos):
    print(f"Running node on port {port}, is_validator: {is_validator}, address: {address}")
    node = algo.Node(address, port, is_validator)
    cli = algo.NodeCLI(node)
    
    node_thread = threading.Thread(target=node.start)
    node_thread.start()
    
    return node, cli

nodes = [6000 + i for i in range(6)]
validators = [6002, 6003, 6004, 6005]
edges = [(6000, 6002), (6000, 6003), (6000, 6004), (6000, 6005), (6001, 6002)]

active_nodes = {node : run_node(node, node in validators, algo = pos) for node in nodes}
for u, v in edges:
    active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
    time.sleep(1)
# Out:
# Running node on port 6000, is_validator: False, address: 127.0.0.1
# Running node on port 6001, is_validator: False, address: 127.0.0.1
# Running node on port 6002, is_validator: True, address: 127.0.0.1
# Running node on port 6003, is_validator: True, address: 127.0.0.1
# Running node on port 6004, is_validator: True, address: 127.0.0.1
# Running node on port 6005, is_validator: True, address: 127.0.0.1

# %%
active_nodes[6000][1].do_sval("")

# %%
active_nodes[6001][1].do_val("")
# Out:
# Validators: set()

# %%
active_nodes[6000][1].do_addtx("user1 10")

# %%
active_nodes[6000][1].do_sval("")

# %%
active_nodes[6000][1].do_val("")
# Out:
# Validators: {6001, 6002, 6003, 6005}

# %%
active_nodes[6004][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1768915463
#   Data: Genesis Block
#   Hash: a0d124058fc32fc329c9ffacfbc41a8b231b43b13caf0b58bba11f38ef9cc89e
#   Previous Hash: 0
#   Mined by: None

# %%
a = set()
a.add((1, 'po'))

# %%
a.add((2, 'po'))
a.add((2, 'pa'))

# %%
max(a)
# Out:
# (2, 'po')

# %%
import poch as poch
import threading
import time
def run_node(port, address = '127.0.0.1', algo = poch):
    print(f"Running node on port {port}, address: {address}")
    node = algo.Node(address, port)
    cli = algo.NodeCLI(node)
    
    node_thread = threading.Thread(target=node.start)
    node_thread.start()
    
    return node, cli

nodes = [6000 + i for i in range(6)]
edges = [(6000, 6002), (6000, 6003), (6000, 6004), (6000, 6005), (6001, 6002)]

active_nodes = {node : run_node(node, algo = poch) for node in nodes}
for u, v in edges:
    active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
    time.sleep(1)
# Out:
# Running node on port 6000, address: 127.0.0.1
# Running node on port 6001, address: 127.0.0.1
# Running node on port 6002, address: 127.0.0.1
# Running node on port 6003, address: 127.0.0.1
# Running node on port 6004, address: 127.0.0.1
# Running node on port 6005, address: 127.0.0.1

# %%
active_nodes[6000][1].do_cval("")

# %%
active_nodes[6000][1].do_addtx("user1 10")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 active_nodes[6000][1].do_addtx("user1 10")
#
# File c:\Users\mohit\Desktop\blockchain-python\poch.py:457, in NodeCLI.do_addtx(self, arg)
#     447     self.node.blockchain.add_transaction(str(self.node.address) + str(self.node.port), recipient, amount)
#     448     self.node.broadcast({
#     449         'type': 'new_transaction',
#     450         'data': {
#    (...)    455         'id': max_msg_id + 1
#     456     })
# --> 457     self.node.poch_consensus()
#     458     # print(f"Transaction added: {str(self.node.address) + str(self.node.port)} sends {amount} coins to {recipient}")
#     459 except ValueError:
#
# File c:\Users\mohit\Desktop\blockchain-python\poch.py:237, in Node.poch_consensus(self)
#     233 while True:
#     234     # Wait for p1 time and collect candidacies
#     235     # time.sleep(2)  # p1 waiting time
#     236     p_candidacies = self.blockchain.candidancies.copy()
# --> 237     candidacies = [v for k, v in p_candidacies.items() if int(self.calculate_hash(int(self.blockchain.c_val, 16) + v), 16) <= self.blockchain.target]
#     239     if len(candidacies) > 15:
#     240         # print("Too many candidacies. Restarting consensus...")
#     241         # time.sleep(2)
#     242         self.blockchain.update_target(len(candidacies))
#
# File c:\Users\mohit\Desktop\blockchain-python\poch.py:237, in <listcomp>(.0)
#     233 while True:
#     234     # Wait for p1 time and collect candidacies
#     235     # time.sleep(2)  # p1 waiting time
#     236     p_candidacies = self.blockchain.candidancies.copy()
# --> 237     candidacies = [v for k, v in p_candidacies.items() if int(self.calculate_hash(int(self.blockchain.c_val, 16) + v), 16) <= self.blockchain.target]
#     239     if len(candidacies) > 15:
#     240         # print("Too many candidacies. Restarting consensus...")
#     241         # time.sleep(2)
#     242         self.blockchain.update_target(len(candidacies))
#
# KeyboardInterrupt:

# %%
active_nodes[6000][1].do_cand("")
# Out:
# {6000: 'a9fe9f84802ca70128cfabf87d7f556ec541a145ed0509c6436ca65d6c37f728', 6004: '2eeea98d45fe2e1ca7e8e80ac9e7947694d2b704c308aa58074191a73c5881cc', 6003: '033a19cff4ee3322b0e4d033aedc4b28ead352bd65d1a17e460f0f8c8a8b5f3f', 6005: '591ce28450a6c4deb85796410e3a58b8caa417ef6e34f0e27e82983070c826e0', 6002: 'af811530bec2acac4b083ae81648ee7866692cc652c23f189f2d7ec36d0e88c5', 6001: '5d604fda312f0d50610d28b7af5c667c815e96341ce1b3992a0db3f0e1bd425b'}

# %%
active_nodes[6002][1].do_listpeers("")
# Out:
# Connected peers:
#   - 127.0.0.1:6000
#   - 127.0.0.1:6001

# %%
active_nodes[6003][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733654632
#   Data: Genesis Block
#   Hash: 340e05886a4a3bc848a72bf25057ba380eecf2afcf3ae8289ae37de5d6334d52
#   Previous Hash: 0
#
# Block 1:
#   Timestamp: 1733654645
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 815544c932e7f89ff2c2e5b146dd645c5328ef60a96bacf905029c4a5b3d51a8
#   Previous Hash: 340e05886a4a3bc848a72bf25057ba380eecf2afcf3ae8289ae37de5d6334d52

# %%
# Out:
# 11579208923731619542357098500868790785326998466564056403945758400791312963993500000

# %%
import m_aasc as m_aasc
import threading
import time
def run_node(port, is_validator, address = '127.0.0.1', algo = m_aasc):
    print(f"Running node on port {port}, is_validator: {is_validator}, address: {address}")
    node = algo.Node(address, port, is_validator)
    cli = algo.NodeCLI(node)
    
    node_thread = threading.Thread(target=node.start)
    node_thread.start()
    
    return node, cli

nodes = [6000 + i for i in range(6)]
validators = [6002, 6003, 6004, 6005]
edges = [(6000, 6002), (6000, 6003), (6000, 6004), (6000, 6005), (6001, 6002)]

active_nodes = {node : run_node(node, node in validators, algo = m_aasc) for node in nodes}
for u, v in edges:
    active_nodes[u][1].do_addpeer(f"127.0.0.1 {v}")
    time.sleep(1)
# Out:
# Running node on port 6000, is_validator: False, address: 127.0.0.1
# Running node on port 6001, is_validator: False, address: 127.0.0.1
# Running node on port 6002, is_validator: True, address: 127.0.0.1
# Running node on port 6003, is_validator: True, address: 127.0.0.1
# Running node on port 6004, is_validator: True, address: 127.0.0.1
# Running node on port 6005, is_validator: True, address: 127.0.0.1

# %%
active_nodes[6000][1].do_sval("")

# %%
active_nodes[6000][1].do_val("")
# Out:
# Validators: {6002, 6003, 6004, 6005}

# %%
active_nodes[6005][1].do_messages("")
# Out:
# Messages: {1, 2}

# %%
active_nodes[6000][1].do_addtx("user1 10")

# %%
active_nodes[6000][1].do_viewchain("")
# Out:
# Block 0:
#   Timestamp: 1733917997
#   Data: Genesis Block
#   Hash: 7e625651fb24c482d73e84e5d407c8307f4def1a2592c215d1c5a65d4da3e354
#   Previous Hash: 0
#   Mined by: None
#
# Block 1:
#   Timestamp: 1733918004
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 1c63ef35a520fad3e6eb4be03d12ae5c19aaf390ea5fac597a180af39eaccdce
#   Previous Hash: 7e625651fb24c482d73e84e5d407c8307f4def1a2592c215d1c5a65d4da3e354
#   Mined by: 6005
#
# Block 2:
#   Timestamp: 1733918008
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 71776389c32c6b218016479c39b122c672cda0edc7de8445a16c98e0a566f8eb
#   Previous Hash: 1c63ef35a520fad3e6eb4be03d12ae5c19aaf390ea5fac597a180af39eaccdce
#   Mined by: 6004
#
# Block 3:
#   Timestamp: 1733918011
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: cc938d12de1befcacd92331dee20a75c80bf95221088bed1bc294dc5eeaf08e1
#   Previous Hash: 71776389c32c6b218016479c39b122c672cda0edc7de8445a16c98e0a566f8eb
#   Mined by: 6005
#
# Block 4:
#   Timestamp: 1733918016
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 676d038742cd162cac66a1c94706a2740cb88c12bc56e2023e3bef4405f05828
#   Previous Hash: cc938d12de1befcacd92331dee20a75c80bf95221088bed1bc294dc5eeaf08e1
#   Mined by: 6004
#
# Block 5:
#   Timestamp: 1733918050
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: c78bab5eb2107c57f46a6df6f3cf855545e4af49b6e8d01d438da58c674aa7c2
#   Previous Hash: 676d038742cd162cac66a1c94706a2740cb88c12bc56e2023e3bef4405f05828
#   Mined by: 6002
#
# Block 6:
#   Timestamp: 1733918112
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 40145a1a7632ed03d5999c336bd0512024123824749b6f7bc4b39461fe16871d
#   Previous Hash: c78bab5eb2107c57f46a6df6f3cf855545e4af49b6e8d01d438da58c674aa7c2
#   Mined by: 6002
#
# Block 7:
#   Timestamp: 1733918125
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 800ef9c3361d2d3c9f7acb78b36891c77deb40dae17bd348773a3a8b90e20378
#   Previous Hash: 40145a1a7632ed03d5999c336bd0512024123824749b6f7bc4b39461fe16871d
#   Mined by: 6003
#
# Block 8:
#   Timestamp: 1733918148
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 3344838d2f3e8b66a8fa67e3b789e8f9aed056b48f560d8e03da85d48b3f2163
#   Previous Hash: 800ef9c3361d2d3c9f7acb78b36891c77deb40dae17bd348773a3a8b90e20378
#   Mined by: 6003
#
# Block 9:
#   Timestamp: 1733918250
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: b7766dfe759e48b365a25073a17087a015ac47e2d135ff9ddd85354bfbbedf7a
#   Previous Hash: 3344838d2f3e8b66a8fa67e3b789e8f9aed056b48f560d8e03da85d48b3f2163
#   Mined by: 6003
#
# Block 10:
#   Timestamp: 1733918286
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: b3813ebac7d028a8295102089991760fdd9cb95492fc2c89f928402bb72a55fb
#   Previous Hash: b7766dfe759e48b365a25073a17087a015ac47e2d135ff9ddd85354bfbbedf7a
#   Mined by: 6004
#
# Block 11:
#   Timestamp: 1733918312
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 8d62cb070102d5779d8f5778c137ab3387d2c0cc110acfe5e20993c0f440f24d
#   Previous Hash: b3813ebac7d028a8295102089991760fdd9cb95492fc2c89f928402bb72a55fb
#   Mined by: 6004
#
# Block 12:
#   Timestamp: 1733918326
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: b23772af6c1f19aac54ba9b9e8abd71634696a375776ce539b840c301ac46aac
#   Previous Hash: 8d62cb070102d5779d8f5778c137ab3387d2c0cc110acfe5e20993c0f440f24d
#   Mined by: 6005
#
# Block 13:
#   Timestamp: 1733918335
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: 0d784f41ffe107bfc24390588cecea27168735233e7892c916f6709a4a15d1a1
#   Previous Hash: b23772af6c1f19aac54ba9b9e8abd71634696a375776ce539b840c301ac46aac
#   Mined by: 6005
#
# Block 14:
#   Timestamp: 1733918342
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: d07f4cd222f69272ba07c777e7f1a1be241ff9a33d1fa38738f0e47d37ef1b8e
#   Previous Hash: 0d784f41ffe107bfc24390588cecea27168735233e7892c916f6709a4a15d1a1
#   Mined by: 6005
#
# Block 15:
#   Timestamp: 1733918370
#   Data: ['127.0.0.16000 sends 10 coins to user1']
#   Hash: bc78933c1c4c583cfcefb0283074f5ee914d98bb387240c536f5a8dbc76e0ffd
#   Previous Hash: d07f4cd222f69272ba07c777e7f1a1be241ff9a33d1fa38738f0e47d37ef1b8e
#   Mined by: 6004

# %%
active_nodes[6002][1].do_logs("")
# Out:
# 6002 VALS: [331.57227739113057, 331.57227739113057, 331.57227739113057, 0.6081974121623507]
# 6002 CUMMULATIVE: [0.33312965 0.6662593  0.99938895 1.        ]
# STAKES: {6002: 12817351199763614874, 6004: 1853106069135275175, 6003: 3885174545196406438, 6005: 7143795875493624890}
# XORED: 0.994611439019405
# 6002 VALS: [331.57227739113057, 331.57227739113057, 0.575363978236944, 3.243719531532537]
# 6002 CUMMULATIVE: [0.49713696 0.99427393 0.99513659 1.        ]
# STAKES: {6002: 9086475199135510458, 6004: 12239637760905362979, 6005: 14003538826232059291, 6003: 7463043827398324813}
# XORED: 0.4454168201138299
# 6002 VALS: [331.57227739113057, 331.57227739113057, 2.589137902066248, 0.16735762598566578]
# 6002 CUMMULATIVE: [0.49793025 0.9958605  0.99974867 1.        ]
# STAKES: {6002: 7638116986989267, 6003: 2735304112823581608, 6004: 11613718750081210603, 6005: 10105942547230103850}
# XORED: 0.03511529167694084
# 6002 VALS: [331.57227739113057, 331.57227739113057, 0.20511171389320582, 0.8033166047311957]
# 6002 CUMMULATIVE: [0.49924082 0.99848163 0.99879046 1.        ]
# STAKES: {6002: 11984642776111199677, 6003: 11517661394646981984, 6004: 516588952316507546, 6005: 16712729644781090050}
# XORED: 0.8486359646310598
# 6002 VALS: [0.38537664004434546, 331.57227739113057, 0.9116076173031371, 0.8925740052568842]
# 6002 CUMMULATIVE: [0.00115465 0.9945944  0.99732572 1.        ]
# STAKES: {6002: 1906330538998194751, 6003: 10520019241338328315, 6004: 3571165469983330952, 6005: 717429741008776140}
# XORED: 0.7029074942175486
# 6002 VALS: [0.11127614563948514, 331.57227739113057, 0.9767224471105039, 0.9563292913466617]
# 6002 CUMMULATIVE: [3.33544985e-04 9.94205769e-01 9.97133448e-01 1.00000000e+00]
# STAKES: {6002: 15192750501495597239, 6003: 12682140071901082777, 6004: 3350555257898732113, 6005: 1953676169912264376}
# XORED: 0.34259362625128076
# 6002 VALS: [1.0515595762931345, 0.3091804321396777, 1.025558569466029, 1.0041457559139948]
# 6002 CUMMULATIVE: [0.31015391 0.40134563 0.70383063 1.        ]
# STAKES: {6002: 4747605103730675243, 6003: 17804561158119430455, 6004: 13411467785867405646, 6005: 8271044542907741124}
# XORED: 0.4927348154656867
# 6002 VALS: [1.0905062272669543, 0.12292058863783588, 1.063542220186993, 1.041336339466365]
# 6002 CUMMULATIVE: [0.32863348 0.36567666 0.6861843  1.        ]
# STAKES: {6002: 16958633447305555308, 6003: 11649911810921055186, 6004: 7381915492935527945, 6005: 12193991956749931056}
# XORED: 0.5224294829917693
# 6002 VALS: [1.1216635480460102, 0.0416981996871198, 1.0939291407637644, 1.0710888063082613]
# 6002 CUMMULATIVE: [0.33699988 0.34952795 0.67819513 1.        ]
# STAKES: {6002: 13010829035476486618, 6004: 9305451077056458365, 6005: 7655959715938961739, 6003: 13412305594947484532}
# XORED: 0.8972339811595939
# 6002 VALS: [1.147155901410692, 0.6931648779157576, 0.17402273882774566, 1.0954317337243578]
# 6002 CUMMULATIVE: [0.36888708 0.59178578 0.64774569 1.        ]
# STAKES: {6002: 14061410470923295019, 6003: 18358855190536029152, 6004: 3980681801209645677, 6005: 13249637073640945273}
# XORED: 0.7392268436080217
# 6002 VALS: [1.168399529214594, 0.714826280350625, 0.05336180084218709, 1.1157175065711054]
# 6002 CUMMULATIVE: [0.38279251 0.61698478 0.63446724 1.        ]
# STAKES: {6002: 12137579431815775007, 6004: 14958147694930729573, 6003: 18395930921322087602, 6005: 4925075307948382743}
# XORED: 0.863117481774749
# 6002 VALS: [1.1863749065871263, 0.7331551593339743, 0.4987276001789024, 0.18526991664804207]
# 6002 CUMMULATIVE: [0.45567979 0.73728048 0.92883889 1.        ]
# STAKES: {6002: 17955187035133906335, 6003: 12759340179654418166, 6004: 16067994116278381120, 6005: 5762371716567450995}
# XORED: 0.8485583213881851
